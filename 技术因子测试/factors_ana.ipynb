# %%
from scutquant import Pipeline

# %%
Pipeline.all_factors_ana("D:/Desktop/workflow")
# Out:
# time used: 156.58780074119568
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1146603 entries, (Timestamp('2006-04-07 00:00:00'), '000001.SZ') to (Timestamp('2022-12-30 00:00:00'), '688981.SH')
# Columns: 168 entries, DIF to label
# dtypes: float64(168)
# memory usage: 1.4+ GB
# None
# X_mis= 0.0009105572016187111
# clean dataset done
#
# split data done
#
# label norm done
#
# The distribution of y_train:
# The distribution of y_valid:
# The distribution of y_test:
# norm data done
#
# all works done
#
# abs all_ic mean: 0.015444646905070039
# abs t-stat mean: 5.3171483302892675
# weighted_average_ic in test set: 0.024697911471515746
# Accuracy of Prediction: 0.5279257294429708
