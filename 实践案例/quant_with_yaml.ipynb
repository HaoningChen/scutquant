# %% [markdown]
# Pipeline是scutquant v0.4.6开始推出的一个高度集成的模块. 旨在让使用者无需了解各模块的具体实现的情况下, 仅填写yaml文件即可使用scutquant完成量化研究的全流程.
#
# Pipeline中包含一个集成所有功能的函数pipeline. 也有在其它模块基础上初步封装的函数, 例如load_data, get_factors等. 可根据自己的需要灵活选择函数搭建自己的workflow.
#
# ## 具体要求:
#
# (1) 一个地址, 需要的所有文件都应放在此目录下. 所有结果也将保存在该目录
#
# (2) 需要all_kwargs.yaml和data文件. data的后缀暂时仅支持csv, xls, xlsx, pkl, pickle, ftr和feather.
#
# (3) all_kwargs.yaml需要包含以下键: "data", "factor", "process", "fit", "prepare", "backtest"和"report".
#
# (4) pipeline函数支持自动生成配置文件. 例如当回测任务使用默认配置时, all_kwargs的"backtest"填null即可.
#
# (5) 为了更好地了解Pipeline模块, 请阅读源代码

# %%
from scutquant import Pipeline

Pipeline.pipeline("D:/Desktop/workflow")
# Out:
# time used: 158.17278265953064
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1146603 entries, (Timestamp('2006-04-07 00:00:00'), '000001.SZ') to (Timestamp('2022-12-30 00:00:00'), '688981.SH')
# Columns: 168 entries, DIF to label
# dtypes: float64(168)
# memory usage: 1.4+ GB
# None
# X_mis= 0.0009105572016187111
# clean dataset done
#
# split data done
#
# label norm done
#
# The distribution of y_train:
# The distribution of y_valid:
# The distribution of y_test:
# norm data done
#
# all works done
#
# Epoch 1/15
# 2363/2363 [==============================] - 70s 29ms/step - loss: 0.9428 - mae: 0.7251 - mape: 1314.6344 - val_loss: 0.9868 - val_mae: 0.7539 - val_mape: 4608.9771
# Epoch 2/15
# 2363/2363 [==============================] - 69s 29ms/step - loss: 0.9029 - mae: 0.7099 - mape: 2395.1572 - val_loss: 0.9276 - val_mae: 0.7209 - val_mape: 4679.9961
# Epoch 3/15
# 2363/2363 [==============================] - 71s 30ms/step - loss: 0.8964 - mae: 0.7074 - mape: 962.5223 - val_loss: 0.9522 - val_mae: 0.7302 - val_mape: 4428.1216
# Epoch 4/15
# 2363/2363 [==============================] - 67s 28ms/step - loss: 0.8906 - mae: 0.7050 - mape: 907.8253 - val_loss: 0.9014 - val_mae: 0.7113 - val_mape: 3915.1387
# Epoch 5/15
# 2363/2363 [==============================] - 67s 28ms/step - loss: 0.8858 - mae: 0.7029 - mape: 825.0770 - val_loss: 0.8952 - val_mae: 0.7086 - val_mape: 1967.2061
# Epoch 6/15
# 2363/2363 [==============================] - 67s 28ms/step - loss: 0.8827 - mae: 0.7015 - mape: 617.4036 - val_loss: 0.8944 - val_mae: 0.7092 - val_mape: 1805.3093
# Epoch 7/15
# 2363/2363 [==============================] - 67s 28ms/step - loss: 0.8811 - mae: 0.7009 - mape: 510.1074 - val_loss: 0.8969 - val_mae: 0.7075 - val_mape: 3487.9197
# Epoch 8/15
# 2363/2363 [==============================] - 68s 29ms/step - loss: 0.8806 - mae: 0.7006 - mape: 567.2386 - val_loss: 0.8930 - val_mae: 0.7075 - val_mape: 2139.5283
# Epoch 9/15
# 2363/2363 [==============================] - 68s 29ms/step - loss: 0.8797 - mae: 0.7001 - mape: 608.6794 - val_loss: 0.8941 - val_mae: 0.7064 - val_mape: 2625.1565
# Epoch 10/15
# 2363/2363 [==============================] - 69s 29ms/step - loss: 0.8790 - mae: 0.6999 - mape: 516.3943 - val_loss: 0.8935 - val_mae: 0.7084 - val_mape: 2968.5818
# Epoch 11/15
# 2363/2363 [==============================] - 69s 29ms/step - loss: 0.8785 - mae: 0.6998 - mape: 698.1521 - val_loss: 0.8938 - val_mae: 0.7060 - val_mape: 2777.5884
# Epoch 12/15
# 2363/2363 [==============================] - 69s 29ms/step - loss: 0.8777 - mae: 0.6996 - mape: 1005.9050 - val_loss: 0.8928 - val_mae: 0.7070 - val_mape: 2109.5188
# Epoch 13/15
# 2363/2363 [==============================] - 69s 29ms/step - loss: 0.8771 - mae: 0.6993 - mape: 677.0631 - val_loss: 0.8945 - val_mae: 0.7080 - val_mape: 3707.1411
# Epoch 14/15
# 2363/2363 [==============================] - 69s 29ms/step - loss: 0.8765 - mae: 0.6990 - mape: 714.7533 - val_loss: 0.8945 - val_mae: 0.7094 - val_mape: 2698.4636
# Epoch 15/15
# 2363/2363 [==============================] - 69s 29ms/step - loss: 0.8759 - mae: 0.6988 - mape: 794.8575 - val_loss: 0.8936 - val_mae: 0.7054 - val_mape: 2735.1018
# Epoch 1/15
# 2363/2363 [==============================] - 79s 31ms/step - loss: 0.9004 - mae: 0.7017 - mape: 516.9921 - val_loss: 0.8977 - val_mae: 0.7083 - val_mape: 1532.8750
# Epoch 2/15
# 2363/2363 [==============================] - 65s 28ms/step - loss: 0.8855 - mae: 0.7012 - mape: 455.8741 - val_loss: 0.8970 - val_mae: 0.7073 - val_mape: 2178.1196
# Epoch 3/15
# 2363/2363 [==============================] - 64s 27ms/step - loss: 0.8848 - mae: 0.7009 - mape: 547.5705 - val_loss: 0.9016 - val_mae: 0.7090 - val_mape: 1626.0260
# Epoch 4/15
# 2363/2363 [==============================] - 65s 28ms/step - loss: 0.8846 - mae: 0.7007 - mape: 530.7188 - val_loss: 0.8964 - val_mae: 0.7065 - val_mape: 2075.0906
# Epoch 5/15
# 2363/2363 [==============================] - 64s 27ms/step - loss: 0.8841 - mae: 0.7005 - mape: 495.9602 - val_loss: 0.8965 - val_mae: 0.7075 - val_mape: 1584.9460
# Epoch 6/15
# 2363/2363 [==============================] - 64s 27ms/step - loss: 0.8835 - mae: 0.7004 - mape: 564.4077 - val_loss: 0.8972 - val_mae: 0.7079 - val_mape: 1814.6349
# Epoch 7/15
# 2363/2363 [==============================] - 64s 27ms/step - loss: 0.8837 - mae: 0.7003 - mape: 553.0986 - val_loss: 0.8970 - val_mae: 0.7095 - val_mape: 1597.0631
# Epoch 8/15
# 2363/2363 [==============================] - 63s 27ms/step - loss: 0.8828 - mae: 0.7002 - mape: 577.6794 - val_loss: 0.8978 - val_mae: 0.7072 - val_mape: 1610.6440
# Epoch 9/15
# 2363/2363 [==============================] - 63s 27ms/step - loss: 0.8836 - mae: 0.7001 - mape: 587.6055 - val_loss: 0.8969 - val_mae: 0.7080 - val_mape: 2038.1719
# Epoch 10/15
# 2363/2363 [==============================] - 63s 27ms/step - loss: 0.8825 - mae: 0.7000 - mape: 728.8394 - val_loss: 0.8966 - val_mae: 0.7088 - val_mape: 1621.8431
# Epoch 11/15
# 2363/2363 [==============================] - 61s 26ms/step - loss: 0.8825 - mae: 0.6999 - mape: 614.2834 - val_loss: 0.8964 - val_mae: 0.7073 - val_mape: 1428.7941
# Epoch 12/15
# 2363/2363 [==============================] - 61s 26ms/step - loss: 0.8827 - mae: 0.6998 - mape: 673.1674 - val_loss: 0.8980 - val_mae: 0.7081 - val_mape: 1035.6742
# Epoch 13/15
# 2363/2363 [==============================] - 61s 26ms/step - loss: 0.8822 - mae: 0.6998 - mape: 647.9631 - val_loss: 0.8969 - val_mae: 0.7084 - val_mape: 1633.0402
# Epoch 14/15
# 2363/2363 [==============================] - 61s 26ms/step - loss: 0.8825 - mae: 0.6997 - mape: 568.6846 - val_loss: 0.8970 - val_mae: 0.7065 - val_mape: 1481.4896
# Epoch 15/15
# 2363/2363 [==============================] - 61s 26ms/step - loss: 0.8820 - mae: 0.6998 - mape: 396.0081 - val_loss: 0.8969 - val_mae: 0.7071 - val_mape: 1331.0845
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: D:/Desktop/workflow/model0/cnn\assets
# INFO:tensorflow:Assets written to: D:/Desktop/workflow/model0/cnn\assets
# WARNING:absl:Found untraced functions such as _update_step_xla, lstm_cell_7_layer_call_fn, lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses while saving (showing 5 of 9). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: D:/Desktop/workflow/model1/bi-lstm\assets
# INFO:tensorflow:Assets written to: D:/Desktop/workflow/model1/bi-lstm\assets
# 8836/8836 [==============================] - 13s 1ms/step
# 8836/8836 [==============================] - 26s 3ms/step
# IC Mean:  0.03598440607537224 ICIR: 0.26037498370358486 Rank IC: 0.03519976598373637 Rank ICIR: 0.2495538900079821
# t-stat of alpha model: 8.117688614301494
# Pearson Correlation Coefficient: 0.029608013848665203
# Accuracy of Prediction: 0.5280593990662218
# Annualized Return: 0.10011416806081597
# Annualized Volatility: 0.08872143996113578
# Annualized Return(Benchmark): 0.09329912899923798
# Annualized Volatility(Benchmark): 0.0920210792432434
#
# Cumulative Rate of Return: 0.4443316103984485
# Cumulative Rate of Return(Benchmark): 0.41015918044655564
# Cumulative Excess Rate of Return: 0.034172429951892846
#
# Max Drawdown: -0.38885158582315094
# Max Drawdown(Benchmark): -0.46217912627483293
# Max Drawdown(Excess Return): -0.21919962608512855
#
# Sharpe Ratio: 2.3678183523756466
# Sortino Ratio: -0.11060894832459893
# Information Ratio: -0.11698697106685749
#
# Beta: 0.9417769357521985
# Alpha: 0.004826394124057443
# Epsilon: 0.03729405157009464
# Profitable Days(%): 0.2945417095777549
